# %%
input()
# Out:
# 658338
# '658338'

# %%
a=input()
# Out:
# 68

# %%
b=2

# %%
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11708/3553919051.py in <module>
# ----> 1 a+b
#
# TypeError: can only concatenate str (not "int") to str

# %%
b+int(a)
# Out:
# 70

# %%
a
# Out:
# '68'

# %%
a.
# Out:
#   File "C:\Users\yrmda\AppData\Local\Temp/ipykernel_11708/3905452595.py", line 1
#     a.
#       ^
# SyntaxError: invalid syntax

# %%
pwd()
# Out:
# 'C:\\Users\\yrmda'
